# %%
import pandas as pd

# %%
import pyarrow.parquet as pq

pf = pq.ParquetFile("data.parquet")

print(pf.schema_arrow.names)
# Out:
# ['url', 'voxel_data', 'title', 'subtitle', 'img', 'user', 'date', 'bigImgs', 'description', 'tags', 'diamondCount', 'views', 'downloads', 'comments', 'favorites', 'downloadLink', 'finalDownloadLink', 'thirdPartyDownloadLink', 'youtubeId']

# %%
import pandas as pd

cols = [
    "url",
    "title",
    "subtitle",
    "img",
    "user",
    "date",
    "description",
    "tags",
    "diamondCount",
    "views",
    "downloads",
    "comments",
    "favorites",
    "downloadLink",
    "finalDownloadLink",
    "thirdPartyDownloadLink",
    "youtubeId"
]

df = pd.read_parquet(
    "data.parquet",
    engine="pyarrow",
    columns=cols
)

df.head()
# Out:
#                                                  url  \
# 0  https://www.planetminecraft.com/project/mediev...
# 1  https://www.planetminecraft.com/project/mediev...
# 2  https://www.planetminecraft.com/project/crimso...
# 3  https://www.planetminecraft.com/project/tie-pr...
# 4  https://www.planetminecraft.com/project/is-2-s...
#
#                                  title            subtitle  \
# 0        Medieval Cottagecore Buidling  Land Structure Map
# 1  Medieval House/Shop/Cottage [Schem]          3D Art Map
# 2    Crimson Witch Hut [Free Download]  Land Structure Map
# 3                         Tie Predator   Air Structure Map
# 4                 IS-2 Schematic (1:1)          3D Art Map
#
#                                                  img          user  \
# 0  https://static.planetminecraft.com/files/image...  SiveNotFound
# 1  https://static.planetminecraft.com/files/image...        nxkill
# 2  https://static.planetminecraft.com/files/image...          baph
# 3  https://static.planetminecraft.com/files/image...  DepthCharger
# 4                                               None  CaptainSlav1
#
#                         date  \
# 0  2020-11-24T15:09:50-05:00
# 1  2020-11-24T14:06:26-05:00
# 2  2020-11-23T21:55:18-05:00
# 3  2020-11-21T09:30:17-05:00
# 4  2020-11-22T11:56:50-05:00
#
#                                          description  \
# 0  a simple building i made recently. I hope you ...
# 1  Howdy! This is a Medieval build that could be ...
# 2  A witch hut transformed using crimson blocks. ...
# 3
# 4  IS-2 Schematic (1:1) If you want to use it som...
#
#                                             tags  diamondCount  views  \
# 0  ["Land Structure", "Medeival", "Cottagecore"]             4     87
# 1                                     ["3d Art"]             4    398
# 2                             ["Land Structure"]             6     99
# 3                              ["Air Structure"]             5    142
# 4               ["3d Art", "Schematic", "Schem"]             1     58
#
#    downloads  comments  favorites  \
# 0         11       2.0          1
# 1        182       2.0          0
# 2         15       2.0          1
# 3         12       0.0          4
# 4          2       1.0          0
#
#                                         downloadLink  \
# 0  https://www.planetminecraft.com/project/mediev...
# 1  https://www.planetminecraft.com/project/mediev...
# 2  https://www.planetminecraft.com/project/crimso...
# 3  https://www.planetminecraft.com/project/tie-pr...
# 4  https://www.planetminecraft.com/project/is-2-s...
#
#                                    finalDownloadLink thirdPartyDownloadLink  \
# 0  https://static.planetminecraft.com/files/resou...                   None
# 1  https://static.planetminecraft.com/files/resou...                   None
# 2  https://static.planetminecraft.com/files/resou...                   None
# 3  https://static.planetminecraft.com/files/resou...                   None
# 4  https://static.planetminecraft.com/files/resou...                   None
#
#   youtubeId
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
